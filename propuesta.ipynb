# %% [raw]
# ---
# title: "Propuesta Desarrollo Software de Gestión de Costo de Vida"
# subtitle:  "'CostOfLiving'"
# author: "Sur Social"
# date: "`r Sys.Date()`"
# format:
#   revealjs:
#     theme: sky
#     css: custom.css
#     slide-number: true
#     transition: fade
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# .title {
#   font-size: 100px;
#   font-style: italic;
#   color: blue;
#   font-family: Arial;
#   font-variant: small-caps;
# }
# ```
#
#
#
# :::  {.smaller}
#
# ## Objetivo del Proyecto
#
# El proyecto "CostOfLiving" tiene como objetivo desarrollar una plataforma que permita a BAT:
#
# 1. Estar informados de manera oportuna sobre la situación de los productores de tabaco.
# 1. Herramientas para el monitoreo de gastos, ingresos y otros factores económicos que afectan la vida de los productores.
# 1. Mantener un repositorio de información histórica de productores, para realizar análisis con facilidad.
# 1. Facilitando la toma de decisiones y la gestión de apoyo a los mismos.
#
# :::
#
# ## Importancia del Proyecto
#
# Este proyecto es crucial para proporcionar a BAT una herramienta que permita monitorear de manera efectiva las condiciones económicas de sus productores, optimizar los recursos de apoyo y mejorar la comunicación y transparencia con los productores.
#
#
# ## Beneficios Esperados
# - Mejora en la gestión y apoyo a productores.
# - Datos precisos para decisiones estratégicas.
# - Herramientas de análisis económico.
#
# # Alcance del Proyecto
#
# ## Descripción General
# - Módulos para gestión de ingresos y gastos.
# - Análisis de datos.
# - Reportes.
# - Recomendaciones personalizadas.
# - Dashboard en tiempo real.
#
# ## Características Principales
# - Registro y seguimiento de ingresos y gastos.
# - Análisis económico.
# - Reportes financieros.
# - Recomendaciones.
# - Dashboard.
#
# ## Limitaciones
# - No incluye integración con sistemas contables externos.
# - No incluye aplicaciones móviles nativas en esta fase.
#
# # Requerimientos del Proyecto
#
# ## Requerimientos Funcionales
# - Gestión de ingresos y gastos.
# - Análisis de datos.
# - Reportes.
# - Recomendaciones.
# - Dashboard en tiempo real.
#
# ## Requerimientos No Funcionales
# - Alta disponibilidad.
# - Rendimiento.
# - Seguridad de datos.
# - Interfaz amigable.
#
# ## Tecnologías a Utilizar
# - Backend: Django
# - Base de Datos: PostgreSQL
# - Infraestructura: Docker
# - Frontend: React
# - Análisis de Datos: Pandas, NumPy
#
# # Plan de Desarrollo
#
# ## Fases del Proyecto
# - **Análisis** (2 semanas)
# - **Diseño** (3 semanas)
# - **Implementación** (8 semanas)
# - **Pruebas** (3 semanas)
# - **Despliegue** (1 semana)
#
# ## Cronograma
# - Línea de tiempo detallada con fechas específicas para cada fase.
#
# ## Metodología de Desarrollo
# - Metodología ágil con iteraciones quincenales.
#
# ## Gestión de Riesgos
# - Posibles retrasos en la integración de datos externos.
# - Mitigación mediante pruebas tempranas.
#
# # Equipo de Trabajo
#
# ## Estructura del Equipo
# - **Ricardo Pizarro**: Líder del Proyecto
# - **Desarrolladores Backend**: [Nombres]
# - **Desarrolladores Frontend**: [Nombres]
# - **Especialistas en Datos**: [Nombres]
# - **QA/Testers**: [Nombres]
#
# ## Currículum del Equipo
# - Breve biografía y experiencia de cada miembro del equipo.
#
# # Presupuesto
#
# ## Costos de Desarrollo
# - Desarrollo de software: $40,000
# - Costos Adicionales: $5,000 en hardware y licencias
#
# ## Plan de Pagos
# - 50% al inicio del proyecto
# - 25% a la mitad del proyecto
# - 25% al finalizar el proyecto
#
# # Plan de Calidad
#
# ## Aseguramiento de Calidad
# - Revisiones periódicas y auditorías de código.
#
# ## Pruebas y Validación
# - Pruebas unitarias, integrales y de aceptación con usuarios finales.
#
# # Mantenimiento y Soporte
#
# ## Plan de Mantenimiento
# - Soporte técnico durante 6 meses post-lanzamiento.
#
# ## Soporte Técnico
# - Disponibilidad 24/7 durante el periodo de mantenimiento.
#
# # Conclusión
#
# ## Resumen Final
# - Solución integral para la gestión de costos de vida de los productores de tabaco.
# - Permitiendo a BAT monitorear la situación de los productores y mejorar la gestión de apoyo.
#
# ## Próximos Pasos
# - Firma del contrato e inicio de la fase de análisis.
#
# # Anexos
#
# ## Documentos Adicionales
# - Diagramas de flujo de datos.
# - Especificaciones técnicas detalladas.
